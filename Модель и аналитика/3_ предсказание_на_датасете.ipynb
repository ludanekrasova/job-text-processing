# %%
from catboost import CatBoostClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
# %matplotlib inline
import joblib
from gensim.models.fasttext import FastText
import pandas as pd
import numpy as np
import re
import difflib
import xlsxwriter
from tqdm.notebook import tqdm
from termcolor import colored, cprint
tqdm.pandas()

# %%
joblib.__version__
# Out:
# '1.1.1'

# %%
def tfidf_featuring(tfidf, df):   
    '''Преобразование текста в мешок слов'''
    X_tfidf = tfidf.transform(df['text'])
    feature_names = tfidf.get_feature_names_out()
    X_tfidf = pd.DataFrame(X_tfidf.toarray(), columns = feature_names, index = df.index)
    
    return X_tfidf

def sentences_split(text):
    # разбивает текст на предложения
    try:
        # TODO оставить точки после числа (?<![0-9])\.  (?<![0-9])\.(?![0-9])
        # TODO удалить текст до требуюутся, трубуется r'требуются:([^<>]+)'
        #разделение на фразы. игнорировать точку после числа. смайлики - разделители |[^\x00-\x7Fа-яА-Я]
        pattern = r'\;| ,|(?<![0-9])\.|\n|\•|—|-|!|обязанности|требования|условия|[^\x00-\x7Fа-яА-Я]'
        sentences = re.compile(pattern).split(text.lower()) 
        #удаляем не буквы в начале и конце фразы
        pattern = r'^[^а-яА-ЯёЁ]+|[^а-яА-ЯёЁ]+$'
        sentences = [re.sub(pattern, '', sen) for sen in sentences]
        return[sen for sen in sentences if len(sen)>0]
    except:
        return []

# %%
def sentences_df(df, part=None):
    # датафрейм для извлечения, part сколько строк извдлекаем
    test_=[]
    idxs = df.index.tolist()
    for idx in idxs[0:part]:
        text = df['responsibilities(Должностные обязанности)'][idx]
        #print(sentences_split(text))
        test_.append(sentences_split(text))
    return test_

# %%
def sort_respons(sentences):
    # сортирует колонку обязанности на три разных
    responsibilities = []
    requirements =[]
    terms=[]
    for idx in tqdm(range(0, len(sentences))):
        test_tfidf = tfidf_featuring(tfidf, pd.DataFrame({"text": sentences[idx]}))
        catc_proba = model.predict_proba(test_tfidf)

        temp_ = pd.DataFrame({"text": sentences[idx]})
        temp_['target']= np.argmax(catc_proba, axis=1)
        temp_['proba']= np.amax(catc_proba, axis=1)
        temp_['target']= temp_['target'].replace({0: "Обязанности", 1: 'Требования', 2: 'Условия работы'}, regex=True)
        #пока без обязанностей
        resp= temp_[(temp_['target']=='Обязанности')&(temp_['proba']>=0.75)]['text'].tolist()
        responsibilities.append(". ".join([i.capitalize() for i in resp]))
        req = temp_[(temp_['target']=='Требования')&(temp_['proba']>=0.75)]['text'].tolist()
        requirements.append(". ".join([i.capitalize() for i in req]))
        ter = temp_[(temp_['target']=='Условия работы')&(temp_['proba']>=0.75)]['text'].tolist()
        terms.append(". ".join([i.capitalize() for i in ter]))
        
    return responsibilities, requirements, terms

# %%
model = CatBoostClassifier(loss_function='MultiClass', random_state=42)
tfidf = TfidfVectorizer()

# %%
# загрузка классификатора
model.load_model('model/model.cbm')
# загрузка векторизатора
tfidf = joblib.load('model/tfidf.pkl')
#model = FastText.load("model/fasttext.model")

# %%
data = pd.read_excel('data/Датасет.xlsx', index_col=0)

# %%
data
# Out:
#             name(название)                      specialization(специализация)  \
# id
# 9495846         Арматурщик                                         Арматурщик
# 9495850         Арматурщик                                         Арматурщик
# 9495851         Арматурщик                                         Арматурщик
# 2               Арматурщик                                         Арматурщик
# 9388857         Арматурщик  Арматурщик Вахта в мcк (питание+проживание) 60/30
# ...                    ...                                                ...
# 9306889            Инженер                                Инженер конструктор
# 9306890          Монтажник                  Монтажник вентиляции/разнорабочий
# 9306891  Слесарь-Ремонтник    Слесарь - автомеханик в цех по ремонту карданов
# 9306892         Арматурщик  Оклейщик автомобилей, полиуретан винил, армату...
# 9306893  Слесарь-Ремонтник                      Слесарь-ремонтник 5-6 разряда
#
#                  responsibilities(Должностные обязанности)  \
# id
# 9495846  Работа на строительных площадках. Очистных соо...
# 9495850  Гнутье арматурной стали на механических станка...
# 9495851                                    Вязка арматуры.
# 2        Выполнение работ по гнутью и резке арматурной ...
# 9388857  Вахта в город Москва.  Обязанности: - армирова...
# ...                                                    ...
# 9306889  Обязанности: Проектирование ультразвуковых пре...
# 9306890  Внимание пока обьявление висит, ведется набор!...
# 9306891  Требуется слесарь в цех по ремонту и балансиро...
# 9306892  🔥 К нам в команду требуются:  🔸 Мастер по окле...
# 9306893  Описание работодателя: Спичечная фабрика ФЭСКО...
#
#                      requirements(Требования к соискателю)  \
# id
# 9495846                                                NaN
# 9495850                                                NaN
# 9495851                                                NaN
# 2        Выполнение работ по гнутью и резке арматурной ...
# 9388857  опыт в строительстве приветствуется; работа в ...
# ...                                                    ...
# 9306889                                                NaN
# 9306890  Приветствуется опыт по установке систем кондиц...
# 9306891  Обучаем. Токарные навыки и сварочные навыки пр...
# 9306892  пыт работы, знание и понимание принципов работ...
# 9306893                                         разряд 5-6
#
#                                             terms(Условия)  \
# id
# 9495846                                                NaN
# 9495850                                                NaN
# 9495851                                                NaN
# 2                                                      NaN
# 9388857  продолжительность вахты 60/30 (продление вахты...
# ...                                                    ...
# 9306889                                    офисные условия
# 9306890   Оплата производится раз в неделю по субботам!...
# 9306891               Зарплата, график работы обсуждаются.
# 9306892                                                NaN
# 9306893  5/2 - 8 часовые смены, в т.ч. в ночь, з/п по к...
#
#         skills(Ключевые навыки)  salary_from salary_to                 object  \
# id
# 9495846                     NaN       150000    170000                    NaN
# 9495850                     NaN       130000    150000                    NaN
# 9495851                     NaN        85000     90000                    NaN
# 2                            \N        50000    100000  ООО "АЛЬМИС_ИНТЕГРАЛ"
# 9388857                     NaN        67000    134000                    NaN
# ...                         ...          ...       ...                    ...
# 9306889                     NaN        35000     35000                    NaN
# 9306890                     NaN         1800     46800                    NaN
# 9306891                     NaN        50000     50000                    NaN
# 9306892                     NaN       120000    200000                    NaN
# 9306893                     NaN        45000     45000                    NaN
#
#                     city  ... updated_by           position        phone  \
# id                        ...
# 9495846     Димитровград  ...         \N         Арматурщик          NaN
# 9495850          Копейск  ...         \N         Арматурщик          NaN
# 9495851        Ярославль  ...         \N         Арматурщик          NaN
# 2                     \N  ...          1         Арматурщик  74959214241
# 9388857          Кировск  ...         \N         Арматурщик          NaN
# ...                  ...  ...        ...                ...          ...
# 9306889         Таганрог  ...         \N            Инженер          NaN
# 9306890        Краснодар  ...         \N          Монтажник          NaN
# 9306891           Москва  ...         \N  Слесарь-Ремонтник          NaN
# 9306892  Санкт-Петербург  ...         \N         Арматурщик          NaN
# 9306893        Череповец  ...         \N  Слесарь-Ремонтник          NaN
#
#                            website                  email image   unique_code  \
# id
# 9495846                         hh               hh@hh.ru    \N   HH-81058502
# 9495850                         hh               hh@hh.ru    \N   HH-80163818
# 9495851                         hh               hh@hh.ru    \N   HH-77729491
# 2        https://almisintegral.ru/  info@almisintegral.ru    \N            \N
# 9388857                      avito         avito@avito.ru    \N  A-3037298578
# ...                            ...                    ...   ...           ...
# 9306889                      avito         avito@avito.ru    \N  A-1580492578
# 9306890                      avito         avito@avito.ru    \N  A-1578246023
# 9306891                      avito         avito@avito.ru    \N   A-928159469
# 9306892                      avito         avito@avito.ru    \N  A-1047100555
# 9306893                      avito         avito@avito.ru    \N  A-1773674397
#
#          city_code source_id                   link_resource
# id
# 9495846         \N         1  https://hh.ru/vacancy/81058502
# 9495850         \N         1  https://hh.ru/vacancy/80163818
# 9495851         \N         1  https://hh.ru/vacancy/77729491
# 2               \N         1                              \N
# 9388857         \N         1     https://avito.ru/3037298578
# ...            ...       ...                             ...
# 9306889         \N         1     https://avito.ru/1580492578
# 9306890         \N         1     https://avito.ru/1578246023
# 9306891         \N         1      https://avito.ru/928159469
# 9306892         \N         1     https://avito.ru/1047100555
# 9306893         \N         1     https://avito.ru/1773674397
#
# [999 rows x 34 columns]

# %%
sentences = sentences_df(data)

# %%
responsibilities, requirements, terms = sort_respons(sentences)
# Out:
#   0%|          | 0/999 [00:00<?, ?it/s]

# %%
#data['responsibilities(Должностные обязанности)'] = responsibilities
data['requirements(Требования к соискателю)'] = requirements
data['terms(Условия)'] = terms

# %%
data[['name(название)', 'responsibilities(Должностные обязанности)', 'requirements(Требования к соискателю)', 'terms(Условия)']]
# Out:
#             name(название)          responsibilities(Должностные обязанности)  \
# id
# 9495846         Арматурщик  Работа на строительных площадках. Очистных соо...
# 9495850         Арматурщик  Гнутье арматурной стали на механических станка...
# 9495851         Арматурщик                                    Вязка арматуры.
# 2               Арматурщик  Выполнение работ по гнутью и резке арматурной ...
# 9388857         Арматурщик  Вахта в город Москва.  Обязанности: - армирова...
# ...                    ...                                                ...
# 9306889            Инженер  Обязанности: Проектирование ультразвуковых пре...
# 9306890          Монтажник  Внимание пока обьявление висит, ведется набор!...
# 9306891  Слесарь-Ремонтник  Требуется слесарь в цех по ремонту и балансиро...
# 9306892         Арматурщик  🔥 К нам в команду требуются:  🔸 Мастер по окле...
# 9306893  Слесарь-Ремонтник  Описание работодателя: Спичечная фабрика ФЭСКО...
#
#                      requirements(Требования к соискателю)  \
# id
# 9495846
# 9495850
# 9495851
# 2
# 9388857                Опыт в строительстве приветствуется
# ...                                                    ...
# 9306889     Знание конструкторских программ приветствуется
# 9306890  Приветствуется опыт по установке систем кондиц...
# 9306891  Работе на балансировочном, сварочном стенде. Т...
# 9306892  Опыт работы, знание и понимание принципов рабо...
# 9306893
#
#                                             terms(Условия)
# id
# 9495846
# 9495850
# 9495851
# 2
# 9388857  Вахта в город москва. Продолжительность вахты ...
# ...                                                    ...
# 9306889
# 9306890  Оплата производится раз в неделю по субботам. ...
# 9306891                Зарплата, график работы обсуждаются
# 9306892
# 9306893    Часовые смены, в т. В ночь, з/п по квалификации
#
# [999 rows x 4 columns]

# %%
data['responsibilities(Должностные обязанности)'] = responsibilities

# %%
data
# Out:
#             name(название)                      specialization(специализация)  \
# id
# 9495846         Арматурщик                                         Арматурщик
# 9495850         Арматурщик                                         Арматурщик
# 9495851         Арматурщик                                         Арматурщик
# 2               Арматурщик                                         Арматурщик
# 9388857         Арматурщик  Арматурщик Вахта в мcк (питание+проживание) 60/30
# ...                    ...                                                ...
# 9306889            Инженер                                Инженер конструктор
# 9306890          Монтажник                  Монтажник вентиляции/разнорабочий
# 9306891  Слесарь-Ремонтник    Слесарь - автомеханик в цех по ремонту карданов
# 9306892         Арматурщик  Оклейщик автомобилей, полиуретан винил, армату...
# 9306893  Слесарь-Ремонтник                      Слесарь-ремонтник 5-6 разряда
#
#                  responsibilities(Должностные обязанности)  \
# id
# 9495846
# 9495850  Гнутье арматурной стали на механических станка...
# 9495851
# 2        Выполнение работ по гнутью и резке арматурной ...
# 9388857          Помощь в прохождение медицинского осмотра
# ...                                                    ...
# 9306889  Проектирование ультразвуковых преобразователей...
# 9306890
# 9306891  Снятие установка валов, разборка сборка и бала...
# 9306892  Мастер по оклейке автомобилей в защитные пленк...
# 9306893                            Ремонт оборудования осн
#
#                      requirements(Требования к соискателю)  \
# id
# 9495846
# 9495850
# 9495851
# 2
# 9388857                Опыт в строительстве приветствуется
# ...                                                    ...
# 9306889     Знание конструкторских программ приветствуется
# 9306890  Приветствуется опыт по установке систем кондиц...
# 9306891  Работе на балансировочном, сварочном стенде. Т...
# 9306892  Опыт работы, знание и понимание принципов рабо...
# 9306893
#
#                                             terms(Условия)  \
# id
# 9495846
# 9495850
# 9495851
# 2
# 9388857  Вахта в город москва. Продолжительность вахты ...
# ...                                                    ...
# 9306889
# 9306890  Оплата производится раз в неделю по субботам. ...
# 9306891                Зарплата, график работы обсуждаются
# 9306892
# 9306893    Часовые смены, в т. В ночь, з/п по квалификации
#
#         skills(Ключевые навыки)  salary_from salary_to                 object  \
# id
# 9495846                     NaN       150000    170000                    NaN
# 9495850                     NaN       130000    150000                    NaN
# 9495851                     NaN        85000     90000                    NaN
# 2                            \N        50000    100000  ООО "АЛЬМИС_ИНТЕГРАЛ"
# 9388857                     NaN        67000    134000                    NaN
# ...                         ...          ...       ...                    ...
# 9306889                     NaN        35000     35000                    NaN
# 9306890                     NaN         1800     46800                    NaN
# 9306891                     NaN        50000     50000                    NaN
# 9306892                     NaN       120000    200000                    NaN
# 9306893                     NaN        45000     45000                    NaN
#
#                     city  ... updated_by           position        phone  \
# id                        ...
# 9495846     Димитровград  ...         \N         Арматурщик          NaN
# 9495850          Копейск  ...         \N         Арматурщик          NaN
# 9495851        Ярославль  ...         \N         Арматурщик          NaN
# 2                     \N  ...          1         Арматурщик  74959214241
# 9388857          Кировск  ...         \N         Арматурщик          NaN
# ...                  ...  ...        ...                ...          ...
# 9306889         Таганрог  ...         \N            Инженер          NaN
# 9306890        Краснодар  ...         \N          Монтажник          NaN
# 9306891           Москва  ...         \N  Слесарь-Ремонтник          NaN
# 9306892  Санкт-Петербург  ...         \N         Арматурщик          NaN
# 9306893        Череповец  ...         \N  Слесарь-Ремонтник          NaN
#
#                            website                  email image   unique_code  \
# id
# 9495846                         hh               hh@hh.ru    \N   HH-81058502
# 9495850                         hh               hh@hh.ru    \N   HH-80163818
# 9495851                         hh               hh@hh.ru    \N   HH-77729491
# 2        https://almisintegral.ru/  info@almisintegral.ru    \N            \N
# 9388857                      avito         avito@avito.ru    \N  A-3037298578
# ...                            ...                    ...   ...           ...
# 9306889                      avito         avito@avito.ru    \N  A-1580492578
# 9306890                      avito         avito@avito.ru    \N  A-1578246023
# 9306891                      avito         avito@avito.ru    \N   A-928159469
# 9306892                      avito         avito@avito.ru    \N  A-1047100555
# 9306893                      avito         avito@avito.ru    \N  A-1773674397
#
#          city_code source_id                   link_resource
# id
# 9495846         \N         1  https://hh.ru/vacancy/81058502
# 9495850         \N         1  https://hh.ru/vacancy/80163818
# 9495851         \N         1  https://hh.ru/vacancy/77729491
# 2               \N         1                              \N
# 9388857         \N         1     https://avito.ru/3037298578
# ...            ...       ...                             ...
# 9306889         \N         1     https://avito.ru/1580492578
# 9306890         \N         1     https://avito.ru/1578246023
# 9306891         \N         1      https://avito.ru/928159469
# 9306892         \N         1     https://avito.ru/1047100555
# 9306893         \N         1     https://avito.ru/1773674397
#
# [999 rows x 34 columns]

# %% [markdown]
# Сохранить новый exel файл

# %%
with pd.ExcelWriter("Решение.xlsx", engine='xlsxwriter') as writer:
    data[['name(название)', 'responsibilities(Должностные обязанности)', 
          'requirements(Требования к соискателю)', 'terms(Условия)', 'skills(Ключевые навыки)'
         ]].to_excel(writer, sheet_name="Результат")
    writer.sheets['Результат'].set_column(1, 1, 20)
    writer.sheets['Результат'].set_column(2, 4, 60)

# %% [markdown]
# ### Проверить точность определения Требований + условий (без разделения)

# %%
# колонка, полученная с помощью формулы в ячейке в режиме разработчика exel
# только зеленый текст responsibilities(Должностные обязанности)
data_val = pd.read_excel('data/Датасет_разделенный.xlsx', index_col=0)[["name(название)", "no_responsibilities"]]

# %%
data_val['no_responsibilities'] = data_val['no_responsibilities'].fillna("")

# %% [markdown]
# #### Сравнить с текстом вакансий, выделенным зеленым
# difflib.SequenceMatcher(isjunk=None, a='', b='', autojunk=True)
# isjunk=None - функция, которая фильтрует мусорные элементы,
# a, b - сравниваемые последовательности,
# autojunk=True - отключение автоматической эвристики мусора.

# %%
def get_similarity(data, data_val):
    # определение схожести выделенных требований и условий с размеченными
    idxs = data.index.tolist()
    diffs=[]
    for idx in idxs:
        if (str(data['requirements(Требования к соискателю)'][idx])!="") & (str(data['terms(Условия)'][idx])!=""):
            str_pred = str(data['requirements(Требования к соискателю)'][idx]).lower() +" "+  str(data['terms(Условия)'][idx]).lower()
        elif str(data['requirements(Требования к соискателю)'][idx])!="":
            str_pred = str(data['requirements(Требования к соискателю)'][idx]).lower()
        else:
            str_pred = str(data['terms(Условия)'][idx]).lower()
            
        str_test = str(data_val['no_responsibilities'][idx]).lower()
        #не учитываем знаки припинания и смайлики
        diff = difflib.SequenceMatcher(lambda x: x == " |;|:|.|!|,|\n|[^\x00-\x7Fа-яА-Я]", str_pred, str_test, autojunk=False).ratio() 
        diffs.append(round(diff, 3))
    return np.average(diffs), diffs

# %%
mean_diff, list_diff = get_similarity(data, data_val)

# %%
mean_diff
# Out:
# 0.7182672672672673

# %%
temp = data_val[['no_responsibilities']].copy()
temp['requirements(Требования к соискателю)'] = data['requirements(Требования к соискателю)']
temp['terms(Условия)'] = data['terms(Условия)']
temp['similarity']=list_diff

# %%
temp[3:12]
# Out:
#                                        no_responsibilities  \
# id
# 2        Выполнение работ по гнутью и резке арматурной ...
# 9388857   опыт в строительстве приветствуетсяпродолжите...
# 9388861  Ставка за смену 3080 руб при графике 6/1 по 11...
# 9388874  опыт в строительстве приветствуется -работа в ...
# 9388888  опыт в строительстве приветствуется; - работа ...
# 9496164
# 9496155
# 9496169
# 9336413  Понимание работы в бригаде  · Дисциплинированн...
#
#                      requirements(Требования к соискателю)  \
# id
# 2
# 9388857                Опыт в строительстве приветствуется
# 9388861  Разряда. Опыт работы от 1 года. Наличие удосто...
# 9388874                Опыт в строительстве приветствуется
# 9388888                Опыт в строительстве приветствуется
# 9496164
# 9496155
# 9496169
# 9336413  Понимание работы в бригаде. Дисциплинированнос...
#
#                                             terms(Условия)  similarity
# id
# 2                                                                0.000
# 9388857  Вахта в город москва. Продолжительность вахты ...       0.665
# 9388861  Предоставляем час обеда + перерывы. Мин. Трудо...       0.683
# 9388874  Продолжительность вахты 60/30 (продление вахты...       0.700
# 9388888  Вахта в город москва. Продолжительность вахты ...       0.689
# 9496164                                                          1.000
# 9496155                                                          1.000
# 9496169                                                          1.000
# 9336413  Продолжительность вахты 60/30, 90/30 (можно бо...       0.808

# %%
temp[temp['similarity']<0.1]
# Out:
#                                        no_responsibilities  \
# id
# 2        Выполнение работ по гнутью и резке арматурной ...
# 9336456
# 9336457
# 9396310
# 9396406
# 9500588  Отличное техническое оснащение малярного цеха....
# 14826
# 9395175  Вакансия Штукатур в строительстве на чистовую ...
# 9395211  Работа Штукатур в Москве. Вакансия Штукатур в ...
# 9492424
# 9492472  монтажник слаботочных систем, КИПиА. Паспорт Р...
# 9492484  Документы РФ (рассмотрим пенсионеров)  График 5/2
# 9492712
# 9492728
# 9492801  Бригады от 2 человек со своим инструментом  С ...
# 9492802
# 9492845
# 9493686                              Опыт работы от 1 года
# 9493751   интересны бригады от двух человек, мобильные,...
# 9493862
# 9493976  монтаж металлоконструкций  Обязанности: работа...
# 9494066                            Установка кондиционеров
# 9494074
# 9494107
# 9494227
# 9494410
# 9306611       Без вредных привычек, рассмотрим пенсионеров
# 9306641  работу монтажник систем кондиционирования и ве...
# 9306680  качественное производство работ и выполнение и...
# 9306717                    выполнять качественно своё дело
# 9306721
# 9306857                                опытом. Граждане РФ
#
#                      requirements(Требования к соискателю)  \
# id
# 2
# 9336456
# 9336457
# 9396310                  Опыт от года. Опыт работы от года
# 9396406  Мы ищем:  активных, ответственных людей, с жел...
# 9500588
# 14826    Знание технологических процессов сварки пнд тр...
# 9395175  Опыт штукатур / штукатур / шпаклевщик если вы ...
# 9395211  Опыт штукатур / штукатур / шпаклевщик если вы ...
# 9492424  Опыт работы сварщиком. Умение работы ручной ду...
# 9492472
# 9492484
# 9492712
# 9492728
# 9492801
# 9492802                   Опыт работы с нержавеющей сталью
# 9492845
# 9493686                              Опыт работы от 1 года
# 9493751
# 9493862
# 9493976
# 9494066
# 9494074  Знание работы на полуавтоматах и их настройки....
# 9494107
# 9494227
# 9494410
# 9306611
# 9306641
# 9306680
# 9306717
# 9306721              Водительского удостоверение категории
# 9306857
#
#                                             terms(Условия)  similarity
# id
# 2                                                                0.000
# 9336456  Вахтовый метод работы 60/30  з/п за месяц. На ...       0.000
# 9336457  Вахтовый метод работы 60/30  з/п за месяц. На ...       0.000
# 9396310  Объект в москве. Премия за выполнение объектов...       0.000
# 9396406  Мы предлагаем. Стабильную заработную плату (2 ...       0.000
# 9500588                                                          0.000
# 14826                                                            0.000
# 9395175         Работа штукатур в москве. Или звоните сами       0.084
# 9395211         Работа штукатур в москве. Или звоните сами       0.090
# 9492424  Зп 80 т. Проезд, проживание, питание. Работа в...       0.000
# 9492472                                                          0.000
# 9492484                                                          0.000
# 9492712  Маляр в отель  график 6/1 по 8 часов или 5/2 п...       0.000
# 9492728  Официальное трудоустройство согласно тк рф. Оп...       0.000
# 9492801                                                          0.000
# 9492802  График работы 5\2 (с 08:00 до. Заработная плат...       0.000
# 9492845  Ремонт(механика, гидравлика)  оплата 340/час д...       0.000
# 9493686  Сантехники  __________________________________...       0.074
# 9493751                                                          0.000
# 9493862                              Вахта 60/30 в брянске       0.000
# 9493976                                                          0.000
# 9494066                                                          0.000
# 9494074  Проезд, проживание, питание. Вахта 60/30 зп 80...       0.000
# 9494107  Многоквартирные дома  проживание. Проезд. Х  р...       0.000
# 9494227  Описание работодателя: автомобильный завод тул...       0.000
# 9494410                              Вахта 60/30 в брянске       0.000
# 9306611                                                          0.000
# 9306641                                                          0.000
# 9306680                                                          0.000
# 9306717                                                          0.000
# 9306721              Стабильная оплата труда. Без задержек       0.000
# 9306857                                                          0.000

# %%
def check_str(str1, str2, color):
    # сравнивает одну строку с другой и раскрашивает в случае отличия
    #pattern = r'[^а-яА-ЯёЁa-zA-Z]'
    #str1 = re.sub(pattern, ' ', str1)
    #str1 = re.sub(" +", " ", str1)
    #str2 = re.sub(pattern, '', str2)
    #str2 = re.sub(" +", " ", str2)
    list1 = str1.lower().split()
    list2 = str2.lower().split()
    new_str1 = ""
    for word in list1:
        if word in list2:
            new_str1 += (word + " ")
        else:
            new_str1 += (colored(word, 'black', color) + " ")
    return new_str1

def check_col(df):
    no_resp, req, term = df.columns
    idxs = df.index.tolist()
    col1=[]
    col2=[]
    col3=[]
    for idx in idxs:
        str1 = df[no_resp][idx]
        str2 = df[req][idx]
        str3 = df[term][idx]
        str4 = df[req][idx] + df[term][idx]
        col1.append(check_str(str1, str4, "on_green"))
        col2.append(check_str(str2, str1, "on_yellow"))
        col3.append(check_str(str3, str1, "on_yellow"))
    df = pd.DataFrame({"no_responsibilities": col1, "requirements(Требования к соискателю)": 
                       col2, "terms(Условия)": col3}, index = idxs)
    return df

# %%
new_df = check_col(temp[['no_responsibilities', 'requirements(Требования к соискателю)', 'terms(Условия)']])
new_df
# Out:
#                                        no_responsibilities  \
# 9495846
# 9495850
# 9495851
# 2        выполнение работ ...
# 9388857  опыт в строительстве приветствуетсяп...
# ...                                                    ...
# 9306889       офисные условия
# 9306890  приветствуется опыт по установке систем ...
# 9306891  обучаем токарные навыки и свароч...
# 9306892  опыт работы, знание и понимание принципов рабо...
# 9306893  разряд 5-6 [...
#
#                      requirements(Требования к соискателю)  \
# 9495846
# 9495850
# 9495851
# 2
# 9388857  опыт в строительстве приветствуется...
# ...                                                    ...
# 9306889  знание конструкторских...
# 9306890  приветствуется опыт по установке систем кондиц...
# 9306891  работе на [3...
# 9306892  опыт работы, знание и понимание принципов рабо...
# 9306893
#
#                                             terms(Условия)
# 9495846
# 9495850
# 9495851
# 2
# 9388857  вахта в город [43...
# ...                                                    ...
# 9306889
# 9306890  оплата производится раз в неделю по ...
# 9306891  зарплата, график работы [3...
# 9306892
# 9306893  часовые смены, в т. в ночь, з/п ...
#
# [999 rows x 3 columns]

# %%
idxs = new_df.index.tolist()
for idx in idxs[993:]:
    print("\033[1m{}\033[0m".format("Вакансия"), idx)
    print("\033[1m{}\033[0m".format("Текст для распознания: "),  new_df['no_responsibilities'][idx])
    print()
    print("\033[1m{}\033[0m".format("Требования: "),  new_df['requirements(Требования к соискателю)'][idx])
    print("\033[1m{}\033[0m".format("Условия: "),  new_df['terms(Условия)'][idx])
    print()
# Out:
# Вакансия 9306888
# Текст для распознания:  отсутствия опыта, обучаеммонтаж воздуховодов, оборудования и систем кондиционирования, 5/2, возможны командировки по башкирии, окладно-премиальная.
#
# Требования:  стаж работы желательно, в случае отсутствия опыта, обучаем, монтаж воздуховодов, оборудования и систем кондиционирования, 5/2, возможны командировки по башкирии, окладно
# Условия:
#
# Вакансия 9306889
# Текст для распознания:  офисные условия
#
# Требования:  знание конструкторских программ приветствуется
# Условия:
#
# Вакансия 9306890
# Текст для распознания:  приветствуется опыт по установке систем кондиционирования оплата производится раз в неделю по субботам! только оклад. сделки нет! работа на постоянной основе график работы 6/1, с 8 до 18:00.
#
# Требования:  приветствуется опыт по установке систем кондиционирования
# Условия:  оплата производится раз в неделю по субботам. только оклад. сделки нет. работа на постоянной основе график работы 6/1, с 8 до
#
# Вакансия 9306891
# Текст для распознания:  обучаем токарные навыки и сварочные навыки приветствуютсязарплата, график работы обсуждаются.
#
# Требования:  работе на балансировочном, сварочном стенде. токарные навыки и сварочные навыки приветствуются
# Условия:  зарплата, график работы обсуждаются
#
# Вакансия 9306892
# Текст для распознания:  опыт работы, знание и понимание принципов работы с материалами различных брендов обязательно! ❗️если вы фрилансер, то возможна работа у нас на аутсорсе ❗️желание расти профессионально, аккуратность, ответственность и стремление сделать максимально качественный результат так же обязательны! требуется мастер с хорошим опытом, ответственный и порядочный
#
# Требования:  опыт работы, знание и понимание принципов работы с материалами различных брендов обязательно. желание расти профессионально, аккуратность, ответственность и стремление сделать максимально качественный результат так же обязательны. требуется мастер с хорошим опытом, ответственный и порядочный. пожалуйста отправляйте краткое резюме о себе нам в сообщения, просто отклики мы не рассматриваем. учеников, помаганов, подаванов и с опытом оклейки пары фар мы не рассматриваем
# Условия:
#
# Вакансия 9306893
# Текст для распознания:  разряд 5-6 условия: 5/2 - 8 часовые смены, в т.ч. в ночь, з/п по квалификации
#
# Требования:
# Условия:  часовые смены, в т. в ночь, з/п по квалификации

# %% [markdown]
# Поисковый бот

# %%
def get_similarity(find, df, n=5):
    # find - запрос соискателя
    # data - таблица с исправленными моделью вакансиями. Бот не будет их считать
    # n - количество выводимых вакансий. закодируй, чтобы красиво было 3-5 штук
    
    #возвращает отфильтвованный датафрейм подходящих вакансий
    data = df.copy()
    idxs = data.index.tolist()
    diffs=[]
    str_find = str(find.lower()) 
    for idx in idxs:
        resp = str(data['responsibilities(Должностные обязанности)'][idx])
        req = str(data['requirements(Требования к соискателю)'][idx])
        term = str(data['terms(Условия)'][idx])
        str_data = resp + " " +  req + " " +  term
        diff = difflib.SequenceMatcher(lambda x: x == " ", str_find, str_data).ratio() 
        diffs.append(round(diff, 3))
        
    data['similarity']=diffs
    #print(data)
    data.sort_values(by='similarity', ascending=False, inplace=True)
   
    # data.head(n)
    return data[0:n]

# %%
#загружаем датасет - результат модели (будет файл)
data_itog = pd.read_excel('Решение.xlsx', index_col=0)
# строка, которую вводит соискатель
find = "слесарь сантехник, работа на сварочном стенде"
# отфильстрованный датасет для визуализации
filter_data = get_similarity(find, data_itog)

# %%
filter_data
# Out:
#                      name(название)  \
# id
# 9493679                   Монтажник
# 9306645                    Штукатур
# 9306839                   Монтажник
# 9306599  Машинист Крана (Крановщик)
# 9306804                   Монтажник
#
#                  responsibilities(Должностные обязанности)  \
# id
# 9493679      Описание работодателя: монтаж систем скуд скс
# 9306645                                                NaN
# 9306839                                                NaN
# 9306599  Следить за техникой и мелкий ремонт своими силами
# 9306804                                                NaN
#
#         requirements(Требования к соискателю)  \
# id
# 9493679                         Знание систем
# 9306645    Аккуратность, дисциплинированность
# 9306839                                   NaN
# 9306599                                   NaN
# 9306804                                   NaN
#
#                                             terms(Условия)  \
# id
# 9493679                                                NaN
# 9306645        Описание работодателя:строительная компания
# 9306839  Заработная плата обговаривается непосредственн...
# 9306599  Официальное трудоустройство. Возможны командир...
# 9306804  Оплата труда достойная, своевременная. Спецодежда
#
#         skills(Ключевые навыки)  similarity
# id
# 9493679                     NaN       0.370
# 9306645                     NaN       0.331
# 9306839                     NaN       0.328
# 9306599                     NaN       0.322
# 9306804                     NaN       0.314

# %%
idxs = filter_data.index.tolist()
idx = idxs[4]
print("Вакансия", filter_data['name(название)'][idx])
print("Должностные обязанности", filter_data['responsibilities(Должностные обязанности)'][idx])
print("Требования к соискателю", filter_data['requirements(Требования к соискателю)'][idx])
print("Условия работы", filter_data['terms(Условия)'][idx])
# Out:
# Вакансия Монтажник
# Должностные обязанности nan
# Требования к соискателю nan
# Условия работы Оплата труда достойная, своевременная. Спецодежда
